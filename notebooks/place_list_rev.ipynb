# %%
import pandas as pd

# %%
df = pd.read_csv('Place List - PlaceList rev..csv')
df
# Out:
#     Port        LAT         LON            Place Name    Alt Place Name  \
# 0    NaN   47.96345   -3.173470                 Bubry            xBubry
# 1    NaN     48.037   -4.666060               Plogoff          xPlogoff
# 2    NaN   48.56726   -3.701420            Plouigneau       xPlouigneau
# 3    NaN   48.62048   -2.133480   Saint-Briac-sur-Mer      xSaint-Briac
# 4    NaN  50.105467    1.836833             Abbeville               NaN
# ..   ...        ...         ...                   ...               ...
# 915    R        NaN         NaN      Terres Australes               NaN
# 916    C        NaN         NaN           New Zealand  Nouvelle-Zélande
# 917    C    -8.7972  162.668000       Solomon Islands      Îles Salomon
# 918  NaN        NaN         NaN                at sea            en mer
# 919  NaN        NaN         NaN  large côte d’Afrique               NaN
#
#      Orig_Class_1/Continent  Orig_Class_2/Country Orig_Class_3     Province  \
# ...

# %%
df.columns
# Out:
# Index(['Port', 'LAT', 'LON', 'Place Name', 'Alt Place Name',
#        'Orig_Class_1/Continent', 'Orig_Class_2/Country', 'Orig_Class_3',
#        'Province', 'working notes (don't need to import!)'],
#       dtype='object')
