# %%
import pandas as pd

# %%
df = pd.read_csv('absent_ships.csv').drop('Unnamed: 0', axis=1)
df
# Out:
#     ship_id ship_name  ship_index ship_code
# 0       364   Achille         363     ACH_C
# 1       370     Aigle         369     AIG_F
# 2       371     Aigle         370     AIG_G
# 3       372      Ajax         371     AJX_B
# 4       373    Alcyon         372     ALC_C
# ..      ...       ...         ...       ...
# 59      574    Valeur         573     VAL_B
# 60      575     Vénus         574     VEN_B
# 61      576  Victoire         575     VIC_D
# 62      580   Vautour         579     VTR_C
# 63      581    Zéphir         580     ZEP_C
#
# [64 rows x 4 columns]

# %%
df1 = pd.read_csv('voyage.csv')
df1
# Out:
#         id voyage_code    date date_voy_begin date_voy_end  notes route_class  \
# 0        4       MUT02  1720.0     15/11/1720   29/04/1721    NaN         NaN
# 1     4444       SUB02  1759.0     22/01/1759   16/03/1760    NaN         NaN
# 2     4445       SUB02  1759.0     22/01/1759   16/03/1760    NaN         NaN
# 3     4446       SUB02  1759.0     22/01/1759   16/03/1760    NaN         NaN
# 4     4447       SUB02  1759.0     22/01/1759   16/03/1760    NaN         NaN
# ...    ...         ...     ...            ...          ...    ...         ...
# 6651  3151       BRT02  1762.0     25/02/1762   21/03/1766    NaN         NaN
# 6652  3152       BRT02  1762.0     25/02/1762   21/03/1766    NaN         NaN
# 6653  3153       BRT02  1762.0     25/02/1762   21/03/1766    NaN         NaN
# 6654  3978       HER04  1767.0     05/02/1767   23/11/1767    NaN         NaN
# 6655    64       AGS07  1777.0     15/11/1777          NaN    NaN         NaN
#
# ...

# %%
df1[df1['ship_code'].isin(list(df['ship_code']))]
# Out:
#         id voyage_code    date date_voy_begin date_voy_end  notes route_class  \
# 42     390       CHA04  1753.0     03/05/1753   15/06/1753    NaN         NaN
# 767   1143       FTN06  1774.0     27/08/1774   24/10/1774    NaN         NaN
# 775   1152       CAT06  1780.0     07/06/1780   13/08/1780    NaN         NaN
# 777   1149       VTR04  1779.0     30/12/1779   17/02/1780    NaN         NaN
# 783   1160       MRP09  1781.0     16/03/1781          NaN    NaN         NaN
# ...    ...         ...     ...            ...          ...    ...         ...
# 6227    41       NEP11  1785.0     05/05/1785   12/03/1786    NaN         NaN
# 6250   171       ALC02  1739.0     05/10/1739          NaN    NaN         NaN
# 6259    73       UNI08  1788.0     03/03/1788          NaN    NaN         NaN
# 6290   358       CYG04  1749.0     03/03/1749          NaN    NaN         NaN
# 6351  6525       STP02  1729.0     18/05/1729   12/11/1729    NaN         NaN
#
# ...

# %%
df2 = pd.read_csv('record.csv')
df2
# Out:
#            id                   file_name      n   age build complexion  \
# 0           1  1722 - Rôle du Solide_2028    1.0   NaN   NaN        NaN
# 1           2  1722 - Rôle du Solide_2028    2.0   NaN   NaN        NaN
# 2           3  1722 - Rôle du Solide_2028    3.0   NaN   NaN        NaN
# 3           4  1722 - Rôle du Solide_2028    4.0   NaN   NaN        NaN
# 4           5  1722 - Rôle du Solide_2028    5.0   NaN   NaN        NaN
# ...       ...                         ...    ...   ...   ...        ...
# 215659  91216         ROLE2P37-III.3_2352  737.0   NaN   NaN        NaN
# 215660  91224         ROLE2P37-III.3_2352  745.0   NaN   NaN        NaN
# 215661  91225         ROLE2P37-III.3_2352  746.0   NaN   NaN        NaN
# 215662  91228         ROLE2P37-III.3_2352  749.0   NaN   NaN        NaN
# 215663  90548         ROLE2P37-III.3_2352   69.0  22.0     m         ch
#
#        conscription wage                                            remarks  \
# ...

# %%
a = list(df['ship_id'])
temp = [i-1 for i in a]

# %%
df2[df2['ship_index'].isin(temp)]
# Out:
# Empty DataFrame
# Columns: [id, file_name, n, age, build, complexion, conscription, wage, remarks, f_n, zot_title, record_index, date_of_birth, date_of_death, medical_issues, passage_paid_by, emb_date, emb_loc, emb_class, disemb_date, disemb_loc, disemb_class, days_on_voyage, earnings, person_index, origin_index, function_index, ship_index, voyage_index]
# Index: []
#
# [0 rows x 29 columns]
