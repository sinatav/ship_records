# %%
import pandas as pd
from tqdm import tqdm

# %%
df = pd.read_csv('_SELECT_r_p_v_vd_FROM_record_r_JOIN_person_p_ON_r_person_index_p_202408261231.csv', low_memory=False).drop('Unnamed: 0', axis=1)

# %%
df[(df['last_name']=='LORIEUX')]
# Out:
#                                                   remarks    emb_date  \
# 45927   a fait la campagne --- domestique du 1er lieut...  09/03/1772
# 46167                                  a fait la campagne  03/01/1739
# 56156   a fait la campagne de Brest à l'île de France ...  28/10/1724
# 59778   a fait la campagne de l'île de France à Lorien...  06/11/1773
# 82789   embarqué à l'armement \n resté à l'île Bourbon...  25/02/1762
# 83114   embarqué à l'armement à l'île de France \n déb...  28/09/1765
# 118346                                 a fait la campagne  03/02/1720
# 119595  remplacement à l'île de France le 07/04/1769 \...         NaN
# 202798  remplacement à l'île de France le 01/01/1766 \...         NaN
#
#                emb_loc emb_class disemb_date               disemb_loc  \
# 45927         Lorient      301.0  17/11/1775                  Lorient
# 46167         Lorient      301.0  23/05/1740                  Lorient
# ...

# %%
len(df)
# Out:
# 215664
