# %%
import pandas as pd
import pickle
from numpy.linalg import norm
import numpy as np

# %%
with open('road.pickle', 'rb') as handle:
    road = pickle.load(handle)
    
with open('cos.pickle', 'rb') as handle:
    cos = pickle.load(handle)

with open('road.pickle', 'rb') as handle:
    road = pickle.load(handle)
    
with open('map.pickle', 'rb') as handle:
    mapp = pickle.load(handle)

with open('pcos.pickle', 'rb') as handle:
    pcos = pickle.load(handle)
    
with open('frac.pickle', 'rb') as handle:
    frac = pickle.load(handle)

# %%
def cosine(num1, num2):
    # Normalize the numbers
    A = [int(i) for i in str(num1)]
    B = [int(i) for i in str(num2)]
    
    return round(np.dot(A,B)/(norm(A)*norm(B)), 4)

# %%
pcos
# Out:
# {2.0: {0.5: 14.23,
#   0.0: 8.64,
#   0.3974: 8.1,
#   0.8944: 7.0,
#   0.7071: 6.46,
#   0.5164: 5.79,
#   0.2887: 5.36,
#   0.169: 5.17,
#   0.1429: 5.09,
#   1.0: 4.34,
#   0.3244: 3.68,
#   0.5883: 3.64,
#   0.8165: 3.52,
#   0.4364: 2.78,
#   0.2774: 2.66,
#   0.4685: 2.04,
#   0.378: 1.53,
#   0.6325: 1.3,
#   0.5547: 1.26,
#   0.2: 1.06,
#   0.4472: 0.98,
#   0.3162: 0.83,
#   0.2425: 0.47,
#   0.6547: 0.47,
#   0.3592: 0.32,
#   0.3333: 0.32,
#   0.8321: 0.32,
#   0.2582: 0.32,
#   0.6963: 0.28,
#   0.4264: 0.28,
#   0.5774: 0.24,
#   0.2294: 0.2,
#   0.2236: 0.2,
#   0.2132: 0.16,
#   0.2673: 0.16,
#   0.5669: 0.12,
#   0.7559: 0.12,
#   0.5388: 0.08,
#   0.4629: 0.08,
#   0.7746: 0.08,
#   0.4851: 0.08,
#   0.9487: 0.08,
#   0.6: 0.08,
#   0.1543: 0.04,
#   0.189: 0.04,
#   0.9177: 0.04,
#   0.6247: 0.04,
#   0.6667: 0.04,
#   0.6761: 0.04,
#   0.1826: 0.04},
#  2333.0: {0.5388: 20.24,
#   0.9323: 17.35,
#   0.9406: 10.99,
#   0.9754: 10.41,
#   0.0: 8.68,
# ...

# %%
{k: v for k, v in sorted(road[2].items(), reverse=True, key=lambda item: item[1])}
# Out:
# {2222: 308,
#  4443: 215,
#  1002: 206,
#  4440: 186,
#  3112: 171,
#  2002: 147,
#  4331: 143,
#  3111: 138,
#  4441: 131,
#  2: 112,
#  4332: 99,
#  3223: 97,
#  3222: 93,
#  2112: 67,
#  4442: 62,
#  4444: 59,
#  112: 57,
#  443: 53,
#  3002: 49,
#  2111: 38,
#  1102: 34,
#  4221: 30,
#  1: 27,
#  4002: 27,
#  1222: 23,
#  3332: 23,
#  11: 21,
#  4001: 16,
#  1001: 15,
#  4112: 15,
#  440: 14,
#  1112: 14,
#  4222: 12,
#  2223: 12,
#  1221: 12,
#  2333: 11,
#  3001: 10,
#  442: 10,
#  2221: 9,
#  2003: 9,
#  3333: 8,
#  1231: 8,
#  4111: 7,
#  3224: 7,
#  2110: 6,
#  444: 6,
#  1333: 5,
#  222: 5,
#  4430: 5,
#  212: 5,
#  1331: 5,
#  4121: 4,
#  3331: 4,
#  2113: 4,
#  1223: 4,
#  321: 4,
#  1111: 4,
#  2001: 4,
#  331: 4,
#  1332: 4,
#  334: 4,
#  3221: 4,
#  1000: 3,
#  4330: 3,
#  0: 3,
#  4003: 3,
#  3443: 3,
#  333: 3,
#  3: 3,
#  4: 3,
#  1004: 3,
#  1443: 2,
#  1114: 2,
#  1334: 2,
#  322: 2,
#  1003: 2,
#  111: 2,
#  441: 2,
#  3233: 2,
#  3442: 2,
#  122: 2,
#  1224: 2,
# ...

# %%
frac
# Out:
# {2: {2222: 10.42,
#   4443: 7.28,
#   1002: 6.97,
#   4440: 6.3,
#   3112: 5.79,
#   2002: 4.98,
#   4331: 4.84,
#   3111: 4.67,
#   4441: 4.44,
#   2: 3.79,
#   4332: 3.35,
#   3223: 3.29,
#   3222: 3.15,
#   2112: 2.27,
#   4442: 2.1,
#   4444: 2.0,
#   112: 1.93,
#   443: 1.8,
#   3002: 1.66,
#   2111: 1.29,
#   1102: 1.15,
#   4221: 1.02,
#   1: 0.92,
#   4002: 0.92,
#   1222: 0.78,
#   3332: 0.78,
#   11: 0.72,
#   4001: 0.55,
#   1001: 0.51,
#   4112: 0.51,
#   440: 0.48,
#   1112: 0.48,
#   4222: 0.41,
#   2223: 0.41,
#   1221: 0.41,
#   2333: 0.38,
#   3001: 0.34,
#   442: 0.34,
#   2221: 0.31,
#   2003: 0.31,
#   3333: 0.28,
#   1231: 0.28,
#   4111: 0.24,
#   3224: 0.24,
#   2110: 0.21,
#   444: 0.21,
#   1333: 0.17,
#   222: 0.17,
#   4430: 0.17,
#   212: 0.17,
#   1331: 0.17,
#   4121: 0.14,
#   3331: 0.14,
#   2113: 0.14,
#   1223: 0.14,
#   321: 0.14,
#   1111: 0.14,
#   2001: 0.14,
#   331: 0.14,
#   1332: 0.14,
#   334: 0.14,
#   3221: 0.14,
#   1000: 0.11,
# ...

# %%
road[1333][3112]
# Out:
# 15

# %%
frac[3002]
# Out:
# {2002: 26.64,
#  3002: 17.93,
#  2112: 14.21,
#  1112: 9.84,
#  1223: 4.05,
#  3222: 3.92,
#  334: 3.49,
#  4222: 2.8,
#  2222: 2.08,
#  3112: 1.56,
#  223: 1.44,
#  3001: 1.24,
#  1222: 1.08,
#  1332: 1.06,
#  4441: 1.0,
#  4440: 0.78,
#  442: 0.77,
#  2012: 0.7,
#  3442: 0.68,
#  4112: 0.49,
#  1002: 0.47,
#  4431: 0.41,
#  2: 0.28,
#  2213: 0.27,
#  4002: 0.25,
#  3333: 0.22,
#  3323: 0.2,
#  1001: 0.18,
#  4443: 0.16,
#  4332: 0.15,
#  331: 0.14,
#  3012: 0.13,
#  222: 0.11,
#  332: 0.11,
#  1122: 0.1,
#  1113: 0.1,
#  4223: 0.09,
#  1233: 0.09,
#  330: 0.09,
#  4341: 0.09,
#  112: 0.07,
#  444: 0.06,
#  111: 0.06,
#  443: 0.05,
#  4444: 0.05,
#  4442: 0.04,
#  1441: 0.04,
#  1440: 0.04,
#  1443: 0.04,
#  333: 0.03,
#  3122: 0.03,
#  4331: 0.03,
#  2000: 0.03,
#  3221: 0.03,
#  1444: 0.03,
#  2232: 0.02,
#  440: 0.02,
#  3332: 0.02,
#  224: 0.02,
#  4: 0.02,
#  1330: 0.02,
#  3: 0.01,
#  1333: 0.01,
#  1114: 0.01,
#  2332: 0.01,
#  2102: 0.01,
#  2122: 0.01,
#  3003: 0.01,
# ...

# %%
pcos
# Out:
# {2.0: {0.5: 14.23,
#   0.0: 8.64,
#   0.3974: 8.1,
#   0.8944: 7.0,
#   0.7071: 6.46,
#   0.5164: 5.79,
#   0.2887: 5.36,
#   0.169: 5.17,
#   0.1429: 5.09,
#   1.0: 4.34,
#   0.3244: 3.68,
#   0.5883: 3.64,
#   0.8165: 3.52,
#   0.4364: 2.78,
#   0.2774: 2.66,
#   0.4685: 2.04,
#   0.378: 1.53,
#   0.6325: 1.3,
#   0.5547: 1.26,
#   0.2: 1.06,
#   0.4472: 0.98,
#   0.3162: 0.83,
#   0.2425: 0.47,
#   0.6547: 0.47,
#   0.3592: 0.32,
#   0.3333: 0.32,
#   0.8321: 0.32,
#   0.2582: 0.32,
#   0.6963: 0.28,
#   0.4264: 0.28,
#   0.5774: 0.24,
#   0.2294: 0.2,
#   0.2236: 0.2,
#   0.2132: 0.16,
#   0.2673: 0.16,
#   0.5669: 0.12,
#   0.7559: 0.12,
#   0.5388: 0.08,
#   0.4629: 0.08,
#   0.7746: 0.08,
#   0.4851: 0.08,
#   0.9487: 0.08,
#   0.6: 0.08,
#   0.1543: 0.04,
#   0.189: 0.04,
#   0.9177: 0.04,
#   0.6247: 0.04,
#   0.6667: 0.04,
#   0.6761: 0.04,
#   0.1826: 0.04},
#  2333.0: {0.5388: 20.24,
#   0.9323: 17.35,
#   0.9406: 10.99,
#   0.9754: 10.41,
#   0.0: 8.68,
# ...
