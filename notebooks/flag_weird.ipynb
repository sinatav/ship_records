# %%
import pandas as pd

file_path = 'crawled_start.csv'
df = pd.read_csv(file_path).drop('Unnamed: 0', axis=1).dropna(how='all', axis=1).dropna(how='all', axis=0)
for col in df.select_dtypes(include=['object']):
    df[col] = df[col].str.strip()

# %%
def match_or_nan(a, b):
    # Function to check if two values are equal or both are NaN
    return (a == b) | (pd.isna(a) & pd.isna(b))

def check_issues(row):
    issues = []
    if not pd.isna(row['Emb_date']) and not pd.Series(row['Emb_date']).str.match(r'^\d{2}/\d{2}/\d{4}$', na=False).bool():
        issues.append('emb_date')
    if not pd.isna(row['Disemb_date']) and not pd.Series(row['Disemb_date']).str.match(r'^\d{2}/\d{2}/\d{4}$', na=False).bool():
        issues.append('disemb_date')
    if pd.isna(row['Emb_loc']):
        issues.append('emb_loc')
    if pd.isna(row['Disemb_loc']):
        issues.append('disemb_loc')
    return issues

# %%
reembark_rows = df[(df['Remarks'].str.contains('rembarqué', na=False, case=False)) & (df['Emb_loc'].isna())]

# Step 5: Process each row with the "rembarqué" keyword individually
for index, row in reembark_rows.iterrows():
    # Find rows with matching 'Last Name', 'First Name', and 'Function', handling NaN values
    matching_rows = df[
        match_or_nan(df['Last Name'], row['Last Name']) &
        match_or_nan(df['First Name'], row['First Name']) &
        match_or_nan(df['Function'], row['Function'])
    ]

    # Sort the matching rows by Emb_date
    sorted_group = matching_rows.sort_values(by=['Emb_date', 'Disemb_date'])

    # Iterate through the sorted group to assign emb_loc based on previous Disemb_loc
    previous_disemb_loc = None
    for i, (sorted_index, sorted_row) in enumerate(sorted_group.iterrows()):
        if sorted_index == index:
            if previous_disemb_loc:
                df.at[sorted_index, 'Emb_loc'] = previous_disemb_loc

        # Update previous_disemb_loc for the next row in the sequence
        previous_disemb_loc = sorted_row['Disemb_loc']
        
for _, group in df.groupby(['Last Name', 'First Name', 'Function'], dropna=False):
    sorted_group = group.sort_values(by=['Emb_date', 'Disemb_date'])
    for i, (index, row) in enumerate(sorted_group.iterrows()):
        if pd.isna(row['Disemb_loc']) and i < len(sorted_group) - 1:
            next_row = sorted_group.iloc[i + 1]
            df.at[index, 'Disemb_loc'] = next_row['Emb_loc']

# %%
df['issued'] = df.apply(check_issues, axis=1)

# %%
for index, row in df.iterrows():
    if row['Disemb_loc'] == 'ration' or row['Disemb_loc'] == 'mer et mort noyé':
        df.at[index, 'issued'].append('disemb_loc')

# %%
df.to_csv('flag_corrupted.csv')

# %%
df[df['issued'].apply(lambda x: len(x) > 0)]
# Out:
#          n                     Last Name            First Name  \
# 1    310.0                      AGOUSTIN                 Colas
# 10   266.0                       AUDRAIN                Pierre
# 48   264.0                          BUCK                Lovell
# 52   185.0           CALIBRE DIT PIERROT                Pierre
# 92   254.0                       DALINOT                 Simon
# 93     1.0            DARGY DE LA CHÂTRE            Christophe
# 192  311.0                          JANY                   Ram
# 205  137.0                     KERDANIEL                   NaN
# 210  121.0                     L'HELIEVE                Gilles
# 225  267.0                       LAVIGNE  Jean François Honoré
# 227  258.0                      LE BERRE              Mathurin
# 251  163.0      LE QUILLEQ DIT ROSPORDEN               Maurice
# 263  265.0           MAGNIEN DIT CHALONS                  Jean
# 296  268.0                        NOUGAY                  Jean
# 310  144.0                        PERRIN                   NaN
# 362  252.0                        SELLER               Georges
# 368  297.0                         SILVE            Marguerite
# 373  215.0                        SOUDAY            Barthélémy
# 381  191.0       THOMASSON DIT THOMASSON          Henri Joseph
# 387  130.0                      TRÉGUIER                Joseph
# 390  196.0  VANNIER DIT SAINTE-MENEHOULT                 Louis
# 395  328.0                         VERLÉ     Jeanne Marguerite
# 399  347.0                       WEFFLET                  Jean
# 405  327.0                           NaN            Constantin
# 408  119.0                           NaN                Joseph
# 411    NaN                           NaN                   NaN
#
#                              Function  \
# 1                      matelot lascar
# 10                passager clandestin
# 48                passager clandestin
# 52                    soldat passager
# 92                    soldat passager
# 93               capitaine [officier]
# 192                    matelot lascar
# 205                 enseigne passager
# 210                            mousse
# 225                  pilotin passager
# 227                           matelot
# 251                   soldat passager
# 263                3e pilote passager
# 296               passager clandestin
# 310  lieutenant des hussards passager
# 362                   soldat passager
# 368                          passager
# 373                  tambour passager
# 381                   soldat passager
# 387                            mousse
# 390                   soldat passager
# 395                          passager
# 399                           matelot
# 405               passager clandestin
# 408                valet [domestique]
# 411                               NaN
#
#                                                Remarks   Age  Wage  \
# 1    supplément à Chandernagor du 01/02/1755 \n dés...  35.0  14.8
# 10   trouvé caché à bord après le départ de Lorient...  16.0   NaN
# 48   trouvé caché à bord après le départ de Lorient...  24.0   NaN
# 52   resté à terre malade au départ de Lorient --- ...   NaN   7.1
# 92   déserté au départ de Lorient --- soldat allema...   NaN   NaN
# 93   à fait la campagne de Lorient à La Corogne ---...   NaN   200
# 192  embarqué en supplément à ? le 10/08/1755 \n dé...   NaN  14.8
# 205  resté à terre au départ de Lorient --- passage...   NaN   NaN
# 210  embarqué à l'armement \n tombé à la mer et mor...  16.0     7
# 225  embarqué par erreur à l'armement \n débarqué à...  15.0     ?
# 227  remplacement à l'armement \n resté à terre au ...  30.0    18
# 251  embarqué à Lorient le 08/03/1754 \n resté à te...   NaN   7.1
# 263  trouvé caché à bord après le départ de Lorient...  29.0    24
# 296  trouvé caché à bord après le départ de Lorient...  12.0   NaN
# 310  resté à terre au départ de Lorient --- passage...   NaN   NaN
# 362  resté à terre malade au départ de Lorient --- ...   NaN   NaN
# 368  embarquée à Chandernagor le 24/02/1755 \n mort...   NaN   NaN
# 373  resté à terre malade à Lorient --- soldat alle...   NaN   NaN
# 381  resté à terre malade au départ de Lorient --- ...   NaN   7.1
# 387  resté à terre au départ de Lorient \n rejoint ...  12.0     6
# 390  resté à terre malade au départ de Lorient --- ...   NaN   7.1
# 395  née en mer à bord le 13/05/1755 \n débarquée à...   0.0   NaN
# 399  remplacement à l'île de France du 19/11/1755 \...   NaN    18
# 405  trouvé caché à bord le 06/03/1755 \n débarqué ...   NaN   NaN
# 408  rembarqué le dit jour et an \n débarqué au dés...  25.0    20
# 411                                                NaN   NaN   NaN
#
#                 Emb_date Disemb_date                Disemb_loc  \
# 1             01/02/1755  19/08/1755                    ration
# 10                 [nan]  05/09/1754                Pondichéry
# 48                 [nan]  10/09/1754                Pondichéry
# 52                 [nan]       [nan]                   Lorient
# 92                 [nan]  08/09/1756                   Lorient
# 93                 [nan]  09/10/1756                la Corogne
# 192           10/08/1755  26/10/1755  Port-Louis île de France
# 205           09/03/1754  09/03/1754                   Lorient
# 210           09/03/1754  31/05/1754          mer et mort noyé
# 225                [nan]  09/03/1754                Pondichéry
# 227           08/09/1756  09/03/1754                   Lorient
# 251           08/03/1754       [nan]                   Lorient
# 263                [nan]  21/09/1755  Port-Louis île de France
# 296                [nan]  24/02/1755              Chandernagor
# 310           09/03/1754  09/03/1754                   Lorient
# 362                [nan]       [nan]                   Lorient
# 368           24/02/1755  28/05/1755                       NaN
# 373                [nan]       [nan]                   Lorient
# 381                [nan]       [nan]                   Lorient
# 387           09/03/1754  08/09/1756                la Corogne
# 390                [nan]       [nan]                   Lorient
# 395           13/05/1755  14/07/1755           l'île de France
# 399           19/11/1755       [nan]              Chandernagor
# 405           06/03/1755  26/10/1755  Port-Louis île de France
# 408  1755-01-22 00:00:00  08/09/1756                la Corogne
# 411                  NaN         NaN                       NaN
#
#                                                   Fate  \
# 1    supplément à Chandernagor du 01/02/1755 \n dés...
# 10   trouvé caché à bord après le départ de Lorient...
# 48                                                 NaN
# 52   resté à terre malade au départ de Lorient --- ...
# 92                                      never boarded!
# 93                                                 NaN
# 192  embarqué en supplément à ? le 10/08/1755 \n dé...
# 205                                                NaN
# 210                                [filled correctly!]
# 225  embarqué par erreur à l'armement \n débarqué à...
# 227                                                NaN
# 251  embarqué à Lorient le 08/03/1754 \n resté à te...
# 263                                                NaN
# 296                                                NaN
# 310                                                NaN
# 362  resté à terre malade au départ de Lorient --- ...
# 368  embarquée à Chandernagor le 24/02/1755 \n mort...
# 373  resté à terre malade à Lorient --- soldat alle...
# 381  resté à terre malade au départ de Lorient --- ...
# 387                                                NaN
# 390  resté à terre malade au départ de Lorient --- ...
# 395                                                NaN
# 399  remplacement à l'île de France du 19/11/1755 \...
# 405  trouvé caché à bord le 06/03/1755 \n débarqué ...
# 408                                                NaN
# 411                                                NaN
#
#      Left La Corunna by barque  Travel expenses          Emb_loc  emb_class  \
# 1                          NaN              NaN     Chandernagor      302.0
# 10                         NaN              NaN          Lorient      304.0
# 48                         NaN              NaN          Lorient      304.0
# 52                         NaN              NaN              NaN      308.0
# 92                         NaN              NaN              NaN        NaN
# 93                         NaN              NaN          Lorient      301.0
# 192                        NaN              NaN              NaN      301.0
# 205                        NaN              NaN              NaN      308.0
# 210                        NaN              NaN          Lorient      301.0
# 225                        NaN              NaN              NaN      301.0
# 227                        NaN              NaN              NaN      301.0
# 251                        NaN              NaN          Lorient      301.0
# 263                        NaN              NaN          Lorient      304.0
# 296                        NaN              NaN          Lorient      304.0
# 310                        NaN              NaN              NaN      308.0
# 362                        NaN              NaN              NaN      308.0
# 368                        NaN              NaN     Chandernagor      301.0
# 373                        NaN              NaN              NaN      308.0
# 381                        NaN              NaN              NaN      308.0
# 387                        NaN              NaN              NaN      301.0
# 390                        NaN              NaN              NaN      308.0
# 395                        NaN              NaN              NaN      305.0
# 399                        NaN              NaN  l'île de France      302.0
# 405                        NaN              NaN              NaN      304.0
# 408                        NaN              NaN     Chandernagor      306.0
# 411                        NaN              NaN              NaN        NaN
#
#      disemb_class                            issued
# 1           304.0                      [disemb_loc]
# 10          303.0                        [emb_date]
# 48          302.0                        [emb_date]
# 52          308.0  [emb_date, disemb_date, emb_loc]
# 92          304.0               [emb_date, emb_loc]
# 93          301.0                        [emb_date]
# 192         302.0                         [emb_loc]
# 205         308.0                         [emb_loc]
# 210         305.0                      [disemb_loc]
# 225         302.0               [emb_date, emb_loc]
# 227         308.0                         [emb_loc]
# 251         308.0                     [disemb_date]
# 263         302.0                        [emb_date]
# 296         302.0                        [emb_date]
# 310         308.0                         [emb_loc]
# 362         308.0  [emb_date, disemb_date, emb_loc]
# 368         305.0                      [disemb_loc]
# 373         308.0  [emb_date, disemb_date, emb_loc]
# 381         308.0  [emb_date, disemb_date, emb_loc]
# 387         302.0                         [emb_loc]
# 390         308.0  [emb_date, disemb_date, emb_loc]
# 395         302.0                         [emb_loc]
# 399         302.0                     [disemb_date]
# 405         302.0                         [emb_loc]
# 408         302.0                        [emb_date]
# 411           NaN             [emb_loc, disemb_loc]
